# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Superstore.csv",encoding="latin1")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 1.6 MB

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Sales"], bins=40, kde=True)

plt.title("Sales Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Profit"], bins=40, kde=True)

plt.title("Profit Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["Sales"])

plt.title("Sales Outliers")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["Profit"])

plt.title("Profit Outliers")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(data = df,x = "Sales", y = "Profit")

plt.title("Sales vs Profit")

plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

category_sales.plot(kind = "bar",figsize = (8,5))

plt.title("Category Wise Sales")

plt.ylabel("Sales")

plt.show()

# %%
category_profit = df.groupby("Category")["Profit"].sum()

category_profit.plot(kind = "bar" ,figsize = (8,5))

plt.title("Category Wise Profit")

plt.ylabel("Profit")

plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind = "bar",figsize = (8,5))

plt.title("Region Wise Sales")

plt.ylabel("Sales")

plt.show()

# %%
segment_sales = df.groupby("Segment")["Sales"].sum()

segment_sales.plot(kind = "bar",figsize = (8,5))

plt.title("Segment Wise Sales")

plt.ylabel("Sales")

plt.show()

# %%
top_states = df.groupby("State")["Sales"].sum()

top_states = top_states.sort_values(
    ascending=False
).head(10)

top_states.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 10 States by Sales")

plt.show()

# %%
top_sub = df.groupby(
    "Sub-Category"
)["Sales"].sum()

top_sub = top_sub.sort_values(
    ascending=False
)

top_sub.head(10).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 10 Sub-Categories")

plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df["Order Date"] = pd.to_datetime(
    df["Order Date"]
)

# %%
df["Month"] = df["Order Date"].dt.month

df["Year"] = df["Order Date"].dt.year

# %%
monthly_sales = df.groupby(
    "Month"
)["Sales"].sum()

monthly_sales.plot(
    kind="line",
    figsize=(10,5),
    marker="o"
)

plt.title("Monthly Sales Trend")

plt.ylabel("Sales")

plt.show()

# %%
df = df[
    (df["Sales"] < 2000) &
    (df["Profit"] > -1000) &
    (df["Profit"] < 1000)
].copy()

print(df.shape)
# Out:
# (9842, 23)

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["Profit"])

plt.title("Profit After Outlier Treatment")

plt.show()

# %%
numeric_df = df.select_dtypes(include="number")

plt.figure(figsize=(10,8))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
from sklearn.model_selection import (train_test_split, cross_val_score)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
categorical_cols = ["Segment", "Region", "Category", "Sub-Category"]
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
columns_to_use = ['Sales', 'Quantity', 'Discount', 'Month', 'Year', 'Segment', 'Region', 'Category', 'Profit']
df_simple = df[columns_to_use]

df_encoded = pd.get_dummies(df_simple, drop_first=True)

# %%
X = df_encoded.drop(columns=['Profit'])
y = df_encoded['Profit']

X_train = X[X['Year'] <= 2016]
y_train = y[X['Year'] <= 2016]

X_test = X[X['Year'] == 2017]
y_test = y[X['Year'] == 2017]

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)

# %%
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

# %%
rf_r2 = r2_score(y_test, y_pred_rf)
lr_r2 = r2_score(y_test, y_pred_lr)
dt_r2 = r2_score(y_test, y_pred_dt)

# %%
rf_mae = mean_absolute_error(y_test, y_pred_rf)
lr_mae = mean_absolute_error(y_test, y_pred_lr)
dt_mae = mean_absolute_error(y_test, y_pred_dt)
# Out:
# MAE: 17.29
# MAE: 37.16
# MAE: 21.65

# %%
rf_rmse = np.sqrt(mean_squared_error(y_test,y_pred_rf))
lr_rmse = np.sqrt(mean_squared_error(y_test,y_pred_lr))
dt_rmse = np.sqrt(mean_squared_error(y_test,y_pred_dt))
# Out:
# RMSE: 43.89
# RMSE: 75.1
# RMSE: 55.97

# %%
print(f"Random Forest R² Score: {rf_r2:.2f}")
print(f"Linear Regression R² Score: {lr_r2:.2f}")
print(f"Decision Tree R² Score: {dt_r2:.2f}")
# Out:
# Random Forest R² Score: 0.77
# Linear Regression R² Score: 0.32
# Decision Tree R² Score: 0.62

# %%
mae = mean_absolute_error(y_test, y_pred_rf)

print("MAE:", round(mae,2))
# Out:
# MAE: 17.29

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred_rf))

print("RMSE:", round(rmse,2))
# Out:
# RMSE: 43.89

# %%
print(f"Linear Regression R² Score: {lr_r2 * 100:.2f}%")
print(f"Decision Tree R² Score: {dt_r2 * 100:.2f}%")
print(f"Random Forest R² Score: {rf_r2 * 100:.2f}%\n")

print(f"Linear Regression MAE: {lr_mae:.2f}")
print(f"Decision Tree MAE: {dt_mae:.2f}")
print(f"Random Forest MAE: {rf_mae:.2f}\n")

print(f"Linear Regression RMSE: {lr_rmse:.2f}")
print(f"Decision Tree RMSE: {dt_rmse:.2f}")
print(f"Random Forest RMSE: {rf_rmse:.2f}")
# Out:
# Linear Regression R² Score: 32.46%
# Decision Tree R² Score: 62.48%
# Random Forest R² Score: 76.93%
#
# Linear Regression MAE: 37.16
# Decision Tree MAE: 21.65
# Random Forest MAE: 17.29
#
# Linear Regression RMSE: 75.10
# Decision Tree RMSE: 55.97
# Random Forest RMSE: 43.89

# %%
print(f"Linear Regression Train R² Score: {lr_model.score(X_train, y_train)*100:.2f}%")
print(f"Linear Regression Test R² Score: {lr_model.score(X_test, y_test)*100:.2f}%\n")

print(f"Decision Tree Train R² Score: {dt_model.score(X_train, y_train)*100:.2f}%")
print(f"Decision Tree Test R² Score: {dt_model.score(X_test, y_test)*100:.2f}%\n")

print(f"Random Forest Train R² Score: {rf_model.score(X_train, y_train)*100:.2f}%")
print(f"Random Forest Test R² Score: {rf_model.score(X_test, y_test)*100:.2f}%")
# Out:
# Linear Regression Train R² Score: 30.49%
# Linear Regression Test R² Score: 32.46%
#
# Decision Tree Train R² Score: 99.98%
# Decision Tree Test R² Score: 62.48%
#
# Random Forest Train R² Score: 96.98%
# Random Forest Test R² Score: 76.93%

# %%
print("Cross Validation Results")
print("-"*90)

lr_cv = cross_val_score(lr_model, X, y, cv=5, scoring="r2")
print("\nLinear Regression CV Scores:", lr_cv)
print(f"Linear Regression Average CV R²: {lr_cv.mean():.4f}\n")

dt_cv = cross_val_score(dt_model, X, y, cv=5, scoring="r2")
print("Decision Tree CV Scores:", dt_cv)
print(f"Decision Tree Average CV R²: {dt_cv.mean():.4f}\n")

rf_cv = cross_val_score(rf_model, X, y, cv=5, scoring="r2")
print("Random Forest CV Scores:", rf_cv)
print(f"Random Forest Average CV R²: {rf_cv.mean():.4f}")
# Out:
# Cross Validation Results
# ------------------------------------------------------------------------------------------
#
# Linear Regression CV Scores: [0.26553746 0.33251628 0.36786141 0.34123999 0.24862885]
# Linear Regression Average CV R²: 0.3112
#
# Decision Tree CV Scores: [0.61551432 0.50173213 0.57610244 0.71640439 0.66395294]
# Decision Tree Average CV R²: 0.6147
#
# Random Forest CV Scores: [0.77945175 0.7287211  0.76149618 0.83610813 0.78836878]
# Random Forest Average CV R²: 0.7788

# %%
results = pd.DataFrame(
{
    "Model":["Linear Regression", "Decision Tree", "Random Forest"],
    "R2 Score":[lr_r2, dt_r2, rf_r2]
}
)

results.sort_values(
    by="R2 Score",
    ascending=False
)
# Out:
#                Model  R2 Score
# 2      Random Forest  0.769312
# 1      Decision Tree  0.624830
# 0  Linear Regression  0.324644

# %%
models = ["Linear Regression", "Decision Tree", "Random Forest"]

scores = [lr_r2 , dt_r2 , rf_r2]

plt.figure(figsize=(8,5))

sns.barplot(x=models, y=scores)

plt.title("Model Comparison (R² Score)")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(y_test, y_pred_rf)

plt.xlabel("Actual Profit")
plt.ylabel("Predicted Profit")

plt.title("Actual vs Predicted Profit")

plt.show()

# %%
importance = pd.DataFrame(
{
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
}
)

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

plt.figure(figsize=(8,5))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature"
)

plt.title("Feature Importance")

plt.show()

# %%
residuals = y_test - y_pred_rf

plt.figure(figsize=(8,5))

sns.histplot(residuals, bins = 30, kde = True)

plt.title("Residual Distribution")

plt.show()

# %% [markdown]
# ### Predictions

# %%
print(X.columns.tolist())
# Out:
# ['Sales', 'Quantity', 'Discount', 'Month', 'Year', 'Segment_Corporate', 'Segment_Home Office', 'Region_East', 'Region_South', 'Region_West', 'Category_Office Supplies', 'Category_Technology']

# %%
sample_input = X.iloc[[0]]

prediction = rf_model.predict(sample_input)

print(
    "Predicted Profit:",
    round(prediction[0], 2)
)

# %%
sample = X_test.iloc[[0]]

sample
# Out:
#      Sales  Quantity  Discount  Month  Year  Segment_Corporate  \
# 12  15.552         3       0.2      4  2017              False
#
#     Segment_Home Office  Region_East  Region_South  Region_West  \
# 12                False        False          True        False
#
#     Category_Office Supplies  Category_Technology
# 12                      True                False

# %%
predicted_profit = rf_model.predict(sample)

print(
    "Actual Profit:",
    round(y_test.iloc[0], 2)
)

print(
    "Predicted Profit:",
    round(predicted_profit[0], 2)
)
# Out:
# Actual Profit: 5.44
# Predicted Profit: 4.54

# %%
predictions = rf_model.predict(
    X_test.head(10)
)

comparison = pd.DataFrame(
{
    "Actual Profit": y_test.head(10).values,
    "Predicted Profit": predictions
}
)

comparison
# Out:
#    Actual Profit  Predicted Profit
# 0         5.4432          4.540288
# 1        -1.0196        -13.604297
# 2         9.9468          5.758628
# 3        16.5564         11.696080
# 4         9.5616         12.644936
# 5         8.7630          8.833257
# 6        -1.9344         -2.038895
# 7        -5.8248         -4.884773
# 8         2.7240          6.721449
# 9       -48.9549         -9.902201

# %%
predictions = rf_model.predict(X_test)

comparison = pd.DataFrame(
{
    "Actual Profit": y_test.values,
    "Predicted Profit": predictions
}
)

comparison.head()
# Out:
#    Actual Profit  Predicted Profit
# 0         5.4432          4.540288
# 1        -1.0196        -13.604297
# 2         9.9468          5.758628
# 3        16.5564         11.696080
# 4         9.5616         12.644936

# %%
comparison.head(20).plot(kind="bar", figsize=(12,5))

plt.title("Actual vs Predicted Profit")

plt.ylabel("Profit")

plt.show()
